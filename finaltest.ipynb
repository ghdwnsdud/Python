# %%
from random import sample
import random
from tqdm import tqdm
import pandas as pd
import requests
import time
import DHB as dhb
import final_df as fd
tqdm.pandas()

# %%
dhb.db_open()
df = dhb.sql("select * from match_aram")
dhb.db_close()
# Out:
# OPEN
# close

# %%
df[df.BOOTS == 0]
# Out:
#                GAMEID  PARTICIPANTID  CHAMPIONID CHAMPIONNAME  SPELL1  SPELL2  \
# 14      KR_5656773843              5          60        Elise      32       4
# 15      KR_5656773843              6          69   Cassiopeia       1       4
# 21      KR_5656732827              2         147    Seraphine       4       3
# 27      KR_5656732827              8         121       Khazix      32       4
# 51      KR_5656615032              2         412       Thresh       3       4
# ...               ...            ...         ...          ...     ...     ...
# 725637  KR_5690308723              8          92        Riven      32       4
# 725646  KR_5690275837              7         350        Yuumi       3      13
# 725648  KR_5690275837              9          69   Cassiopeia       6       4
# 725659  KR_5690306267             10          69   Cassiopeia       6       4
# 725663  KR_5690300589              4         202         Jhin       6       4
#
#                        MAIN_RUNE        SUB_RUNE       STAT_RUNE  TEAMID  ...  \
# 14      8100|8128|8126|8138|8135  8000|8009|8014  5002|5008|5008     100  ...
# 15      8200|8230|8226|8234|8236  8000|8009|9105  5001|5008|5007     200  ...
# 21      8100|8128|8126|8138|8106  8000|8014|8009  5003|5002|5008     100  ...
# 27      8100|8128|8143|8138|8135  8000|8014|9111  5002|5008|5007     200  ...
# 51      8300|8351|8306|8321|8410  8000|9105|8009  5001|5003|5007     100  ...
# ...                          ...             ...             ...     ...  ...
# 725637  8000|8010|9111|9105|8299  8100|8106|8126  5003|5002|5007     200  ...
# 725646  8200|8229|8226|8210|8237  8000|8009|8017  5002|5008|5007     200  ...
# 725648  8000|8010|8009|9105|8017  8100|8135|8138  5003|5008|5007     200  ...
# 725659  8000|8010|8009|9103|8014  8100|8126|8106  5002|5008|5008     200  ...
# 725663  8100|8128|8139|8138|8106  8000|9103|8009  5003|5008|5008     100  ...
#
#         SELFMITIGATEDDAMAGE  TOTALTIMECCDEALT  TIMECCINGOTHERS  \
# 14                     5867                28               27
# 15                     7944               554               19
# 21                     5443               140               25
# 27                    11714               168               12
# 51                    12483               173               28
# ...                     ...               ...              ...
# 725637                12434                43               26
# 725646                 9545               100               40
# 725648                16160               367               52
# 725659                 8503               708               51
# 725663                 4491                95               28
#
#         LARGESTKILLINGSPREE  GOLDEARNED        STARTING_ITEM  MAIN_ITEM_BUILD  \
# 14                        2       11076       2003|2003|3802        6655|4629
# 15                        3       10245  1027|1052|2031|3070   6653|3003|4629
# 21                        2        9341       2003|3070|3112   6617|3011|3003
# 27                        3        9798       1036|1036|3070   6695|6692|3004
# 51                        0        7003       2003|2051|3070        3083|3119
# ...                     ...         ...                  ...              ...
# 725637                    5        7420       1001|2031|2051             6630
# 725646                    0       13492       2003|2003|3802   6655|3011|4645
# 725648                    3       17123            3070|3112   6653|3003|4637
# 725659                    3       11863                 3802   6656|3116|3165
# 725663                    3       12879       1036|1037|2031   6671|3036|3094
#
#         SUB_ITEM_BUILD  BOOTS                          SKILL_BUILD
# 14                   0      0        1|2|3|1|1|4|1|2|1|2|4|2|2|3|3
# 15                   0      0        1|2|3|1|1|4|1|3|1|3|4|3|3|2|2
# 21                   0      0          1|2|3|2|2|4|2|3|2|1|4|1|1|1
# 27                   0      0      1|2|3|2|2|4|2|2|1|2|1|4|4|1|1|3
# 51                   0      0                3|1|2|2|2|4|2|1|2|1|4
# ...                ...    ...                                  ...
# 725637               0      0                1|2|3|1|1|4|1|3|1|3|4
# 725646            3089      0  1|1|3|3|1|4|1|3|1|3|4|1|2|3|2|4|2|2
# 725648       4645|3116      0  1|2|3|3|3|4|3|1|3|1|4|1|1|2|2|4|2|2
# 725659            3135      0      1|2|3|3|3|4|3|1|3|1|4|1|1|2|2|4
# 725663               0      0      1|2|3|1|1|4|1|2|1|2|4|2|2|3|3|4
#
# [38013 rows x 31 columns]

# %%
test = df.groupby(["GAMEID"])[['PARTICIPANTID']].count()
test[test.PARTICIPANTID != 10]
# Out:
# Empty DataFrame
# Columns: [PARTICIPANTID]
# Index: []

# %%
df = pd.read_csv("725700.csv")

# %% [markdown]
# # . 최종DF 컬럼에 넣기

# %%
final_df = fd.final_df(df)
final_df = final_df[["CHAMPIONNAME","RUNE_IMG_ONE","RUNE_IMG_TWO","SPELL_IMG","STARTING_ITEM_IMG_ONE","STARTING_ITEM_IMG_TWO","MAIN_ITEM_BUILD_IMG",
                     "BOOTS_IMG","SKILL_IMG","SKILL_KEY","SYNERGY_TIER","COMBINATION_SCORE","K_SYNERGY"]].T.drop_duplicates().T
# Out:
# C:\Users\lunat\WorkPython\FinalProject\final_df.py:648: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SEPLL_LST"] = df.apply(lambda x: sepll_lst(x), axis=1)
# C:\Users\lunat\WorkPython\FinalProject\final_df.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["WIN"] = df.apply(lambda x: 1 if x["WIN"] == True else 0 , axis=1)
# C:\Users\lunat\WorkPython\FinalProject\final_df.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MAIN"] = df.apply(lambda x: x["MAIN_RUNE"].split("|")[0], axis=1)
# C:\Users\lunat\WorkPython\FinalProject\final_df.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SUB"] = df.apply(lambda x: x["SUB_RUNE"].split("|")[0], axis=1)
# C:\Users\lunat\WorkPython\FinalProject\final_df.py:463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SKILL_BUILD"] = df.apply(lambda x: x.SKILL_BUILD.split("|"), axis=1)
# C:\Users\lunat\WorkPython\FinalProject\final_df.py:464: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SKILL_BUILD"] = df.apply(lambda x: skill_tree(x), axis=1)

# %%
final_df.columns
# Out:
# Index(['CHAMPIONNAME', 'RUNE_IMG_ONE', 'RUNE_IMG_TWO', 'SPELL_IMG',
#        'STARTING_ITEM_IMG_ONE', 'STARTING_ITEM_IMG_TWO', 'MAIN_ITEM_BUILD_IMG',
#        'BOOTS_IMG', 'SKILL_IMG', 'SKILL_KEY', 'SYNERGY_TIER',
#        'COMBINATION_SCORE', 'K_SYNERGY'],
#       dtype='object')

# %%
final_df
# Out:
#     CHAMPIONNAME                                       RUNE_IMG_ONE  \
# 0         Aatrox  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 1           Ahri  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 2          Akali  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 3         Akshan  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 4        Alistar  https://ddragon.leagueoflegends.com/cdn/img/pe...
# ..           ...                                                ...
# 152          Zed  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 153        Ziggs  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 154       Zilean  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 155          Zoe  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 156         Zyra  https://ddragon.leagueoflegends.com/cdn/img/pe...
#
#                                           RUNE_IMG_TWO  \
# 0    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 1    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 2    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 3    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 4    https://ddragon.leagueoflegends.com/cdn/img/pe...
# ..                                                 ...
# 152  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 153  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 154  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 155  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 156  https://ddragon.leagueoflegends.com/cdn/img/pe...
#
#                                              SPELL_IMG  \
# 0    https://ddragon.leagueoflegends.com/cdn/11.24....
# 1    https://ddragon.leagueoflegends.com/cdn/11.24....
# 2    https://ddragon.leagueoflegends.com/cdn/11.24....
# 3    https://ddragon.leagueoflegends.com/cdn/11.24....
# 4    https://ddragon.leagueoflegends.com/cdn/11.24....
# ..                                                 ...
# 152  https://ddragon.leagueoflegends.com/cdn/11.24....
# 153  https://ddragon.leagueoflegends.com/cdn/11.24....
# 154  https://ddragon.leagueoflegends.com/cdn/11.24....
# 155  https://ddragon.leagueoflegends.com/cdn/11.24....
# 156  https://ddragon.leagueoflegends.com/cdn/11.24....
#
#                                  STARTING_ITEM_IMG_ONE  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 1    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 2    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 3    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 4    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# ..                                                 ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 153  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 154  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 155  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 156  http://ddragon.leagueoflegends.com/cdn/11.24.1...
#
#                                  STARTING_ITEM_IMG_TWO  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 1    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 2    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 3    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 4    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# ..                                                 ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 153  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 154  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 155  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 156  http://ddragon.leagueoflegends.com/cdn/11.24.1...
#
#                                    MAIN_ITEM_BUILD_IMG  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 1    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 2    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 3    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 4    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# ..                                                 ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 153  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 154  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 155  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 156  http://ddragon.leagueoflegends.com/cdn/11.24.1...
#
#                                              BOOTS_IMG  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 1    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 2    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 3    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 4    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# ..                                                 ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 153  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 154  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 155  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 156  http://ddragon.leagueoflegends.com/cdn/11.24.1...
#
#                                              SKILL_IMG SKILL_KEY  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 1    http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|W|E
# 2    http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 3    http://ddragon.leagueoflegends.com/cdn/11.24.1...     E|Q|W
# 4    http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|W|E
# ..                                                 ...       ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 153  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 154  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|W|E
# 155  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 156  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
#
#                                           SYNERGY_TIER  \
# 0    Ivern|Seraphine|Nami|Zyra|Alistar|Leona|Anivia...
# 1    Kindred|Alistar|Nami|Sona|Ashe|Maokai|XinZhao|...
# 2    Seraphine|KogMaw|Senna|Sona|Nami|Rell|Ashe|Jin...
# 3    Sona|Taric|KogMaw|Kled|Yorick|Rammus|Karthus|I...
# 4    Sona|Sivir|Orianna|Darius|Viktor|Olaf|Seraphin...
# ..                                                 ...
# 152  Seraphine|Sona|Ivern|Nami|Maokai|Lillia|Lulu|S...
# 153  Sona|RekSai|Annie|Maokai|Skarner|Nautilus|Sera...
# 154  Lillia|Nami|Ivern|Seraphine|Maokai|Viego|Janna...
# 155  Seraphine|Sona|Taliyah|Caitlyn|Yorick|Janna|Na...
# 156  Sona|Seraphine|Aatrox|KogMaw|Nami|Varus|Yuumi|...
#
#                                      COMBINATION_SCORE  \
# 0    14.1%|13.5%|12.4%|11.6%|10.3%|9.1%|8.2%|8.2%|7...
# 1    13.6%|12.3%|12.0%|11.9%|11.4%|10.4%|9.8%|8.8%|...
# 2    14.9%|13.9%|13.3%|11.8%|9.9%|9.8%|9.1%|8.8%|8....
# 3    14.7%|14.6%|14.5%|14.3%|13.1%|12.7%|11.4%|11.2...
# 4    19.8%|11.5%|11.5%|11.3%|10.7%|10.5%|10.2%|9.5%...
# ..                                                 ...
# 152  15.0%|13.6%|13.3%|12.1%|10.3%|9.8%|9.4%|9.3%|8...
# 153  15.7%|11.9%|10.7%|9.8%|9.7%|8.9%|8.2%|8.2%|8.2...
# 154  15.3%|14.9%|14.1%|12.4%|12.0%|11.5%|10.3%|10.3...
# 155  15.2%|12.7%|12.2%|11.2%|10.7%|10.5%|10.2%|10.1...
# 156  19.6%|12.6%|12.3%|11.0%|10.9%|10.0%|9.9%|9.8%|...
#
#                                              K_SYNERGY
# 0    아이번|세라핀|나미|자이라|알리스타|레오나|애니비아|마오카이|애쉬|유미|빅토르|블라...
# 1    킨드레드|알리스타|나미|소나|애쉬|마오카이|신 짜오|카사딘|바루스|베이가|카밀|렝가...
# 2    세라핀|코그모|세나|소나|나미|렐|애쉬|징크스|시비르|갱플랭크|바루스|직스|알리스타...
# 3    소나|타릭|코그모|클레드|요릭|람머스|카서스|일라오이|그웬|브랜드|세라핀|직스|제이...
# 4    소나|시비르|오리아나|다리우스|빅토르|올라프|세라핀|나미|하이머딩거|브랜드|제이스|...
# ..                                                 ...
# 152  세라핀|소나|아이번|나미|마오카이|릴리아|룰루|세나|렉사이|레넥톤|제라스|케이틀린|...
# 153  소나|렉사이|애니|마오카이|스카너|노틸러스|세라핀|케이틀린|베인|나미|오리아나|아이...
# 154  릴리아|나미|아이번|세라핀|마오카이|비에고|잔나|코그모|모르가나|소나|케이틀린|키아...
# 155  세라핀|소나|탈리야|케이틀린|요릭|잔나|나미|스카너|마오카이|우디르|브라움|룰루|그...
# 156  소나|세라핀|아트록스|코그모|나미|바루스|유미|렉사이|나서스|릴리아|트런들|애쉬|탐...
#
# [157 rows x 13 columns]

# %%
def champ_img(name):
    champion_lst = []
    url = 'http://ddragon.leagueoflegends.com/cdn/11.23.1/img/champion/'+name+'.png'
    #champion_lst.append(name)
    champion_lst.append(res["data"][name]["name"])
    champion_lst.append(res["data"][name]["id"])
    champion_lst.append(url)
    return champion_lst

# %%
url = "https://ddragon.leagueoflegends.com/cdn/11.24.1/data/ko_KR/champion.json"
res = requests.get(url).json()
champ_lst = list(res["data"].keys())
champ_key = list(map(lambda x: res["data"][x]["key"], champ_lst))
champion = dict(list(zip(champ_key, champ_lst)))
tmp = list(map(lambda x: champ_img(x), champ_lst))
champion = dict(list(zip(champ_key, tmp)))

# %%
test = pd.DataFrame(champion).T
test = test.rename(columns={0:"CHAMPNAME",1:"CHAMPIONNAME",2:"CHAMP_IMG"})
test.reset_index(inplace=True)
test = test.rename(columns={"index":"CHAMP_CODE"})
test[test.CHAMPIONNAME =="Fiddlesticks"] = test[test.CHAMPIONNAME =="Fiddlesticks"].replace("Fiddlesticks","FiddleSticks")
testing = pd.merge(test, final_df, on="CHAMPIONNAME")

# %%
test.to_csv("CHAMP_LST.csv",header=True, index=False, encoding="utf-8-sig")

# %%
champ_tier = pd.read_csv("champ_tier.csv")
champ_tier = champ_tier.rename(columns={"CHAMPIONNAME":"CHAMPNAME"})

# %%
champ_tier
# Out:
#     CHAMPNAME  PICK    WIN   KDA  tier POSITION
# 0        아트록스  0.86  51.66  3.06     2     AD전사
# 1          아리  0.63  44.30  3.13     5     AP딜러
# 2         아칼리  0.79  43.32  2.59     5     AP딜러
# 3         아크샨  0.53  43.90  2.96     5     AD딜러
# 4        알리스타  0.65  53.78  3.54     2  AP전사&탱커
# ..        ...   ...    ...   ...   ...      ...
# 152        제드  1.00  45.18  2.84     5     AD딜러
# 153        직스  0.89  55.60  4.06     2     AP딜러
# 154       질리언  0.54  45.45  4.92     4     AP딜러
# 155        조이  0.73  44.83  3.36     5     AP딜러
# 156       자이라  0.51  51.12  3.55     3     AP딜러
#
# [157 rows x 6 columns]

# %%
testing = pd.merge(testing, champ_tier, on="CHAMPNAME")

# %%
testing.to_csv("CHAMPINFO.csv",header=True, index=False, encoding="utf-8-sig")

# %%
testing
# Out:
#     CHAMP_CODE CHAMPNAME CHAMPIONNAME  \
# 0          266      아트록스       Aatrox
# 1          103        아리         Ahri
# 2           84       아칼리        Akali
# 3          166       아크샨       Akshan
# 4           12      알리스타      Alistar
# ..         ...       ...          ...
# 152        238        제드          Zed
# 153        115        직스        Ziggs
# 154         26       질리언       Zilean
# 155        142        조이          Zoe
# 156        143       자이라         Zyra
#
#                                              CHAMP_IMG  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.23.1...
# 1    http://ddragon.leagueoflegends.com/cdn/11.23.1...
# 2    http://ddragon.leagueoflegends.com/cdn/11.23.1...
# 3    http://ddragon.leagueoflegends.com/cdn/11.23.1...
# 4    http://ddragon.leagueoflegends.com/cdn/11.23.1...
# ..                                                 ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.23.1...
# 153  http://ddragon.leagueoflegends.com/cdn/11.23.1...
# 154  http://ddragon.leagueoflegends.com/cdn/11.23.1...
# 155  http://ddragon.leagueoflegends.com/cdn/11.23.1...
# 156  http://ddragon.leagueoflegends.com/cdn/11.23.1...
#
#                                           RUNE_IMG_ONE  \
# 0    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 1    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 2    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 3    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 4    https://ddragon.leagueoflegends.com/cdn/img/pe...
# ..                                                 ...
# 152  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 153  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 154  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 155  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 156  https://ddragon.leagueoflegends.com/cdn/img/pe...
#
#                                           RUNE_IMG_TWO  \
# 0    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 1    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 2    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 3    https://ddragon.leagueoflegends.com/cdn/img/pe...
# 4    https://ddragon.leagueoflegends.com/cdn/img/pe...
# ..                                                 ...
# 152  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 153  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 154  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 155  https://ddragon.leagueoflegends.com/cdn/img/pe...
# 156  https://ddragon.leagueoflegends.com/cdn/img/pe...
#
#                                              SPELL_IMG  \
# 0    https://ddragon.leagueoflegends.com/cdn/11.24....
# 1    https://ddragon.leagueoflegends.com/cdn/11.24....
# 2    https://ddragon.leagueoflegends.com/cdn/11.24....
# 3    https://ddragon.leagueoflegends.com/cdn/11.24....
# 4    https://ddragon.leagueoflegends.com/cdn/11.24....
# ..                                                 ...
# 152  https://ddragon.leagueoflegends.com/cdn/11.24....
# 153  https://ddragon.leagueoflegends.com/cdn/11.24....
# 154  https://ddragon.leagueoflegends.com/cdn/11.24....
# 155  https://ddragon.leagueoflegends.com/cdn/11.24....
# 156  https://ddragon.leagueoflegends.com/cdn/11.24....
#
#                                  STARTING_ITEM_IMG_ONE  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 1    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 2    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 3    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 4    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# ..                                                 ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 153  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 154  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 155  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 156  http://ddragon.leagueoflegends.com/cdn/11.24.1...
#
#                                  STARTING_ITEM_IMG_TWO  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 1    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 2    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 3    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 4    http://ddragon.leagueoflegends.com/cdn/11.24.1...
# ..                                                 ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 153  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 154  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 155  http://ddragon.leagueoflegends.com/cdn/11.24.1...
# 156  http://ddragon.leagueoflegends.com/cdn/11.24.1...
#
#                                    MAIN_ITEM_BUILD_IMG  ...  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
# 1    http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
# 2    http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
# 3    http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
# 4    http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
# ..                                                 ...  ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
# 153  http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
# 154  http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
# 155  http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
# 156  http://ddragon.leagueoflegends.com/cdn/11.24.1...  ...
#
#                                              SKILL_IMG SKILL_KEY  \
# 0    http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 1    http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|W|E
# 2    http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 3    http://ddragon.leagueoflegends.com/cdn/11.24.1...     E|Q|W
# 4    http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|W|E
# ..                                                 ...       ...
# 152  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 153  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 154  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|W|E
# 155  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
# 156  http://ddragon.leagueoflegends.com/cdn/11.24.1...     Q|E|W
#
#                                           SYNERGY_TIER  \
# 0    Ivern|Seraphine|Nami|Zyra|Alistar|Leona|Anivia...
# 1    Kindred|Alistar|Nami|Sona|Ashe|Maokai|XinZhao|...
# 2    Seraphine|KogMaw|Senna|Sona|Nami|Rell|Ashe|Jin...
# 3    Sona|Taric|KogMaw|Kled|Yorick|Rammus|Karthus|I...
# 4    Sona|Sivir|Orianna|Darius|Viktor|Olaf|Seraphin...
# ..                                                 ...
# 152  Seraphine|Sona|Ivern|Nami|Maokai|Lillia|Lulu|S...
# 153  Sona|RekSai|Annie|Maokai|Skarner|Nautilus|Sera...
# 154  Lillia|Nami|Ivern|Seraphine|Maokai|Viego|Janna...
# 155  Seraphine|Sona|Taliyah|Caitlyn|Yorick|Janna|Na...
# 156  Sona|Seraphine|Aatrox|KogMaw|Nami|Varus|Yuumi|...
#
#                                      COMBINATION_SCORE  \
# 0    14.1%|13.5%|12.4%|11.6%|10.3%|9.1%|8.2%|8.2%|7...
# 1    13.6%|12.3%|12.0%|11.9%|11.4%|10.4%|9.8%|8.8%|...
# 2    14.9%|13.9%|13.3%|11.8%|9.9%|9.8%|9.1%|8.8%|8....
# 3    14.7%|14.6%|14.5%|14.3%|13.1%|12.7%|11.4%|11.2...
# 4    19.8%|11.5%|11.5%|11.3%|10.7%|10.5%|10.2%|9.5%...
# ..                                                 ...
# 152  15.0%|13.6%|13.3%|12.1%|10.3%|9.8%|9.4%|9.3%|8...
# 153  15.7%|11.9%|10.7%|9.8%|9.7%|8.9%|8.2%|8.2%|8.2...
# 154  15.3%|14.9%|14.1%|12.4%|12.0%|11.5%|10.3%|10.3...
# 155  15.2%|12.7%|12.2%|11.2%|10.7%|10.5%|10.2%|10.1...
# 156  19.6%|12.6%|12.3%|11.0%|10.9%|10.0%|9.9%|9.8%|...
#
#                                              K_SYNERGY  PICK    WIN   KDA  \
# 0    아이번|세라핀|나미|자이라|알리스타|레오나|애니비아|마오카이|애쉬|유미|빅토르|블라...  0.86  51.66  3.06
# 1    킨드레드|알리스타|나미|소나|애쉬|마오카이|신 짜오|카사딘|바루스|베이가|카밀|렝가...  0.63  44.30  3.13
# 2    세라핀|코그모|세나|소나|나미|렐|애쉬|징크스|시비르|갱플랭크|바루스|직스|알리스타...  0.79  43.32  2.59
# 3    소나|타릭|코그모|클레드|요릭|람머스|카서스|일라오이|그웬|브랜드|세라핀|직스|제이...  0.53  43.90  2.96
# 4    소나|시비르|오리아나|다리우스|빅토르|올라프|세라핀|나미|하이머딩거|브랜드|제이스|...  0.65  53.78  3.54
# ..                                                 ...   ...    ...   ...
# 152  세라핀|소나|아이번|나미|마오카이|릴리아|룰루|세나|렉사이|레넥톤|제라스|케이틀린|...  1.00  45.18  2.84
# 153  소나|렉사이|애니|마오카이|스카너|노틸러스|세라핀|케이틀린|베인|나미|오리아나|아이...  0.89  55.60  4.06
# 154  릴리아|나미|아이번|세라핀|마오카이|비에고|잔나|코그모|모르가나|소나|케이틀린|키아...  0.54  45.45  4.92
# 155  세라핀|소나|탈리야|케이틀린|요릭|잔나|나미|스카너|마오카이|우디르|브라움|룰루|그...  0.73  44.83  3.36
# 156  소나|세라핀|아트록스|코그모|나미|바루스|유미|렉사이|나서스|릴리아|트런들|애쉬|탐...  0.51  51.12  3.55
#
#      tier  POSITION
# 0       2      AD전사
# 1       5      AP딜러
# 2       5      AP딜러
# 3       5      AD딜러
# 4       2   AP전사&탱커
# ..    ...       ...
# 152     5      AD딜러
# 153     2      AP딜러
# 154     4      AP딜러
# 155     5      AP딜러
# 156     3      AP딜러
#
# [157 rows x 21 columns]
